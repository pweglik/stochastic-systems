# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def plotting(data):
    # Setting the style with seaborn
    sns.set(style="whitegrid")


    # Create a plot with seaborn and make background transparent
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.plot(data["total_steps"], data["best_score"], marker='*', linestyle=':', label='Best Score')

    # Adding titles and labels
    ax.set_title('Performance Metrics Over Training Steps')
    ax.set_xlabel('Total Training Steps')
    ax.set_ylabel('Fitness')
    ax.legend()

    # Save as SVG with transparent background
    plt.tight_layout()
    fig.patch.set_alpha(0) # Making the background of the figure transparent
    ax.patch.set_alpha(0) # Making the background of the axes transparent
    # plt.savefig("asdasdsad.svg", format='svg', transparent=True)

# %%
data = pd.read_pickle("./results/HalfCheetah-v4-run2/log.pkl")
plotting(data)

# %%
data = pd.read_pickle("./results_no_im/HalfCheetah-v4-run2/log.pkl")
plotting(data)

# %%
data = pd.read_pickle("./results_evo/HalfCheetah-v4-run3/log.pkl")
plotting(data)

# %%
# 300k iters, tournament selection - no importance mixing
data = pd.read_pickle("./results_no_im/HalfCheetah-v4-run7/log.pkl")
plotting(data)

# %%
#300k iters, tournament selection - evolution stategy
data = pd.read_pickle("./results_evo/HalfCheetah-v4-run5/log.pkl")
plotting(data)

# %%
#300k iters, tournament selection - importance mixing
data = pd.read_pickle("./results/HalfCheetah-v4-run6/log.pkl")
plotting(data)

# %%
# 300k iters, roulette selection + one point crossover - no importance mixing
data = pd.read_pickle("./results_no_im/HalfCheetah-v4-run8/log.pkl")
plotting(data)

# %%
#300k iters, roulette selection + one point crossover - evolution stategy
data = pd.read_pickle("./results_evo/HalfCheetah-v4-run8/log.pkl")
plotting(data)

# %%
#300k iters, roulette selection + one point crossover - importance mixing
data = pd.read_pickle("./results/HalfCheetah-v4-run7/log.pkl")
plotting(data)
